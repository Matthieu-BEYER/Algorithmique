# %% [markdown]
# # <center> TD 1 : Utilisation de Turtle </center>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1zIwy0PPfp6PEnqKg8W_dGdoxO_JGQUwc#scrollTo=DayhRN6utrKP)

# %% [markdown]
# <div class="alert alert-warning">   <div style="text-align:justify;"> <b> <u> Exercice 1 :</u> </b> Tracer la figure ci-dessous. <br>
# La figure est constitué de 100 carrés. Chaque carré tourne de 10° vers la gauche. Entre deux carrés successifs la longueur du côté diminue de 2 pixels. </div> </div>

# %% [markdown]
# ![Capture%20d%E2%80%99%C3%A9cran%202021-11-22%20110710.jpg](attachment:Capture%20d%E2%80%99%C3%A9cran%202021-11-22%20110710.jpg)

# %% [markdown]
# <div class="alert alert-warning">   <div style="text-align:justify;"> <b> <u> Exercice 2 :</u> </b> Tracer la figure ci-dessous. <br>
# La figure est constitué de 12 carrés. Le plus grand carré fait 400 pixels. Avant de dessiner on placera le stylo à la coordonnée (-200;-200).
#     </div> </div>

# %% [markdown]
# ![Capture%20d%E2%80%99%C3%A9cran%202021-11-22%20105929.jpg](attachment:Capture%20d%E2%80%99%C3%A9cran%202021-11-22%20105929.jpg)

# %% [markdown]
# <div class="alert alert-warning">   <div style="text-align:justify;"> <b> <u> Exercice 3 :</u> </b> Tracer la figure ci-dessous. <br>
# La figure est constitué de 400 triangles rectangles. Chaque triangle tourne de 5° vers la gauche. Entre deux triangles successifs la longueur du côté diminue d'un pixel. </div> </div>

# %% [markdown]
# ![Capture%20d%E2%80%99%C3%A9cran%202021-11-23%20004853.jpg](attachment:Capture%20d%E2%80%99%C3%A9cran%202021-11-23%20004853.jpg)
